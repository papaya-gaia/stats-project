# %% [markdown]
# ## Libraries

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf
from scipy.stats import chi2_contingency, f_oneway

# %% [markdown]
# ## Dataset

# %%
data = pd.read_csv("C:/Users/lasko/Downloads/NEW_OFFICIAL_cleaned_data_without_outliers.csv")
data.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#          Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 0  2016-12-03       2.5      3067         2         1    1     202.0
# 1  2016-02-04       2.5      3067         2         1    0     156.0
# 2  2017-03-04       2.5      3067         3         2    0     134.0
# 3  2017-03-04       2.5      3067         3         2    1      94.0
# 4  2016-06-04       2.5      3067         3         1    2     120.0
#
#    BuildingArea  YearBuilt  Lattitude  Longtitude             Regionname  \
# 0    118.675000       1900   -37.7996    144.9984  Northern Metropolitan
# 1     79.000000       1900   -37.8079    144.9934  Northern Metropolitan
# 2    150.000000       1900   -37.8093    144.9944  Northern Metropolitan
# 3     98.886364       2011   -37.7969    144.9969  Northern Metropolitan
# 4    142.000000       2014   -37.8072    144.9941  Northern Metropolitan
#
#    Propertycount
# 0           4019
# 1           4019
# 2           4019
# 3           4019
# 4           4019

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# Number of Bedrooms - categories
# - 0
# - 1
# - 2-3
# - 4-5
# - more than 5

# %%
def categorize_bedroom2(value):
    if value == 0:
        return 'Group_0'
    elif value == 1:
        return 'Group_1'
    elif value in [2, 3]:
        return 'Group_2_3'
    elif value in [4, 5]:
        return 'Group_4_5'
    else:
        return 'Group_6_or_more'

data['Bedroom2_Group'] = data['Bedroom2'].apply(categorize_bedroom2)

data = pd.get_dummies(data, columns=['Bedroom2_Group'], prefix='Bedroom2', drop_first=False)
data.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#          Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 0  2016-12-03       2.5      3067         2         1    1     202.0
# 1  2016-02-04       2.5      3067         2         1    0     156.0
# 2  2017-03-04       2.5      3067         3         2    0     134.0
# 3  2017-03-04       2.5      3067         3         2    1      94.0
# 4  2016-06-04       2.5      3067         3         1    2     120.0
#
#    BuildingArea  YearBuilt  Lattitude  Longtitude             Regionname  \
# 0    118.675000       1900   -37.7996    144.9984  Northern Metropolitan
# 1     79.000000       1900   -37.8079    144.9934  Northern Metropolitan
# 2    150.000000       1900   -37.8093    144.9944  Northern Metropolitan
# 3     98.886364       2011   -37.7969    144.9969  Northern Metropolitan
# 4    142.000000       2014   -37.8072    144.9941  Northern Metropolitan
#
#    Propertycount  Bedroom2_Group_0  Bedroom2_Group_1  Bedroom2_Group_2_3  \
# 0           4019             False             False                True
# 1           4019             False             False                True
# 2           4019             False             False                True
# 3           4019             False             False                True
# 4           4019             False             False                True
#
#    Bedroom2_Group_4_5  Bedroom2_Group_6_or_more
# 0               False                     False
# 1               False                     False
# 2               False                     False
# 3               False                     False
# 4               False                     False

# %% [markdown]
# Number of Rooms - for >= 6, set 6

# %%
data['Rooms'] = data['Rooms'].apply(lambda x: 6 if x >= 6 else x)
data.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#          Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 0  2016-12-03       2.5      3067         2         1    1     202.0
# 1  2016-02-04       2.5      3067         2         1    0     156.0
# 2  2017-03-04       2.5      3067         3         2    0     134.0
# 3  2017-03-04       2.5      3067         3         2    1      94.0
# 4  2016-06-04       2.5      3067         3         1    2     120.0
#
#    BuildingArea  YearBuilt  Lattitude  Longtitude             Regionname  \
# 0    118.675000       1900   -37.7996    144.9984  Northern Metropolitan
# 1     79.000000       1900   -37.8079    144.9934  Northern Metropolitan
# 2    150.000000       1900   -37.8093    144.9944  Northern Metropolitan
# 3     98.886364       2011   -37.7969    144.9969  Northern Metropolitan
# 4    142.000000       2014   -37.8072    144.9941  Northern Metropolitan
#
#    Propertycount  Bedroom2_Group_0  Bedroom2_Group_1  Bedroom2_Group_2_3  \
# 0           4019             False             False                True
# 1           4019             False             False                True
# 2           4019             False             False                True
# 3           4019             False             False                True
# 4           4019             False             False                True
#
#    Bedroom2_Group_4_5  Bedroom2_Group_6_or_more
# 0               False                     False
# 1               False                     False
# 2               False                     False
# 3               False                     False
# 4               False                     False

# %% [markdown]
# Car - categories
# - 0
# - 1
# - 2
# - 3 - 4
# - more than 4

# %%
def categorize_car_direct(value):
    if value == 0:
        return 0
    elif value == 1:
        return 1
    elif value == 2:
        return 2
    elif value in [3, 4]:
        return 3
    else:
        return 4

# Apply the direct mapping to create a new categorical column
data['Car_Category'] = data['Car'].apply(categorize_car_direct)

# Create dummies using this numerical mapping
car_dummies = pd.get_dummies(data['Car_Category'], prefix='Car', drop_first=False)

data = pd.concat([data, car_dummies], axis=1)

data.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#          Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 0  2016-12-03       2.5      3067         2         1    1     202.0
# 1  2016-02-04       2.5      3067         2         1    0     156.0
# 2  2017-03-04       2.5      3067         3         2    0     134.0
# 3  2017-03-04       2.5      3067         3         2    1      94.0
# 4  2016-06-04       2.5      3067         3         1    2     120.0
#
#    BuildingArea  YearBuilt  Lattitude  Longtitude             Regionname  \
# 0    118.675000       1900   -37.7996    144.9984  Northern Metropolitan
# 1     79.000000       1900   -37.8079    144.9934  Northern Metropolitan
# 2    150.000000       1900   -37.8093    144.9944  Northern Metropolitan
# 3     98.886364       2011   -37.7969    144.9969  Northern Metropolitan
# 4    142.000000       2014   -37.8072    144.9941  Northern Metropolitan
#
#    Propertycount  Bedroom2_Group_0  Bedroom2_Group_1  Bedroom2_Group_2_3  \
# 0           4019             False             False                True
# 1           4019             False             False                True
# 2           4019             False             False                True
# 3           4019             False             False                True
# 4           4019             False             False                True
#
#    Bedroom2_Group_4_5  Bedroom2_Group_6_or_more  Car_Category  Car_0  Car_1  \
# 0               False                     False             1  False   True
# 1               False                     False             0   True  False
# 2               False                     False             0   True  False
# 3               False                     False             1  False   True
# 4               False                     False             2  False  False
#
#    Car_2  Car_3  Car_4
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False
# 3  False  False  False
# 4   True  False  False

# %% [markdown]
# Bathrooms - for >=4, set 4

# %%
data['Bathroom'] = data['Bathroom'].apply(lambda x: 4 if x >= 4 else x)
data.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#          Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 0  2016-12-03       2.5      3067         2         1    1     202.0
# 1  2016-02-04       2.5      3067         2         1    0     156.0
# 2  2017-03-04       2.5      3067         3         2    0     134.0
# 3  2017-03-04       2.5      3067         3         2    1      94.0
# 4  2016-06-04       2.5      3067         3         1    2     120.0
#
#    BuildingArea  YearBuilt  Lattitude  Longtitude             Regionname  \
# 0    118.675000       1900   -37.7996    144.9984  Northern Metropolitan
# 1     79.000000       1900   -37.8079    144.9934  Northern Metropolitan
# 2    150.000000       1900   -37.8093    144.9944  Northern Metropolitan
# 3     98.886364       2011   -37.7969    144.9969  Northern Metropolitan
# 4    142.000000       2014   -37.8072    144.9941  Northern Metropolitan
#
#    Propertycount  Bedroom2_Group_0  Bedroom2_Group_1  Bedroom2_Group_2_3  \
# 0           4019             False             False                True
# 1           4019             False             False                True
# 2           4019             False             False                True
# 3           4019             False             False                True
# 4           4019             False             False                True
#
#    Bedroom2_Group_4_5  Bedroom2_Group_6_or_more  Car_Category  Car_0  Car_1  \
# 0               False                     False             1  False   True
# 1               False                     False             0   True  False
# 2               False                     False             0   True  False
# 3               False                     False             1  False   True
# 4               False                     False             2  False  False
#
#    Car_2  Car_3  Car_4
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False
# 3  False  False  False
# 4   True  False  False

# %% [markdown]
# YearSold

# %%
data['Date'] = pd.to_datetime(data['Date'], errors='coerce')

# %%
data['YearSold'] = data['Date'].dt.year
data.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 0 2016-12-03       2.5      3067         2         1    1     202.0
# 1 2016-02-04       2.5      3067         2         1    0     156.0
# 2 2017-03-04       2.5      3067         3         2    0     134.0
# 3 2017-03-04       2.5      3067         3         2    1      94.0
# 4 2016-06-04       2.5      3067         3         1    2     120.0
#
#    BuildingArea  YearBuilt  Lattitude  Longtitude             Regionname  \
# 0    118.675000       1900   -37.7996    144.9984  Northern Metropolitan
# 1     79.000000       1900   -37.8079    144.9934  Northern Metropolitan
# 2    150.000000       1900   -37.8093    144.9944  Northern Metropolitan
# 3     98.886364       2011   -37.7969    144.9969  Northern Metropolitan
# 4    142.000000       2014   -37.8072    144.9941  Northern Metropolitan
#
#    Propertycount  Bedroom2_Group_0  Bedroom2_Group_1  Bedroom2_Group_2_3  \
# 0           4019             False             False                True
# 1           4019             False             False                True
# 2           4019             False             False                True
# 3           4019             False             False                True
# 4           4019             False             False                True
#
#    Bedroom2_Group_4_5  Bedroom2_Group_6_or_more  Car_Category  Car_0  Car_1  \
# 0               False                     False             1  False   True
# 1               False                     False             0   True  False
# 2               False                     False             0   True  False
# 3               False                     False             1  False   True
# 4               False                     False             2  False  False
#
#    Car_2  Car_3  Car_4  YearSold
# 0  False  False  False      2016
# 1  False  False  False      2016
# 2  False  False  False      2017
# 3  False  False  False      2017
# 4   True  False  False      2016

# %% [markdown]
# HouseAge

# %%
data['HouseAge'] = data['YearSold'] - data['YearBuilt']

# %% [markdown]
# Grouping by Regionname - based on Average Housing Prices by Region Map

# %%
region_groups = {
    'Northern Metropolitan': 'N_S_SE_Metropolitan',
    'Southern Metropolitan': 'N_S_SE_Metropolitan',
    'South-Eastern Metropolitan': 'N_S_SE_Metropolitan',
    'Eastern Metropolitan': 'E_Metropolitan',
    'Western Metropolitan': 'W_Metropolitan',
    'Western Victoria': 'W_N_E_Victoria',
    'Northern Victoria': 'W_N_E_Victoria',
    'Eastern Victoria': 'W_N_E_Victoria'
}

# Map the 'Regionname' column to the new region groups
data['RegionGroup'] = data['Regionname'].map(region_groups)

# Create dummy variables for the new RegionGroup
data = pd.get_dummies(data, columns=['RegionGroup'], drop_first=False)
data.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 0 2016-12-03       2.5      3067         2         1    1     202.0
# 1 2016-02-04       2.5      3067         2         1    0     156.0
# 2 2017-03-04       2.5      3067         3         2    0     134.0
# 3 2017-03-04       2.5      3067         3         2    1      94.0
# 4 2016-06-04       2.5      3067         3         1    2     120.0
#
#    BuildingArea  YearBuilt  Lattitude  Longtitude             Regionname  \
# 0    118.675000       1900   -37.7996    144.9984  Northern Metropolitan
# 1     79.000000       1900   -37.8079    144.9934  Northern Metropolitan
# 2    150.000000       1900   -37.8093    144.9944  Northern Metropolitan
# 3     98.886364       2011   -37.7969    144.9969  Northern Metropolitan
# 4    142.000000       2014   -37.8072    144.9941  Northern Metropolitan
#
#    Propertycount  Bedroom2_Group_0  Bedroom2_Group_1  Bedroom2_Group_2_3  \
# 0           4019             False             False                True
# 1           4019             False             False                True
# 2           4019             False             False                True
# 3           4019             False             False                True
# 4           4019             False             False                True
#
#    Bedroom2_Group_4_5  Bedroom2_Group_6_or_more  Car_Category  Car_0  Car_1  \
# 0               False                     False             1  False   True
# 1               False                     False             0   True  False
# 2               False                     False             0   True  False
# 3               False                     False             1  False   True
# 4               False                     False             2  False  False
#
#    Car_2  Car_3  Car_4  YearSold  HouseAge  RegionGroup_E_Metropolitan  \
# 0  False  False  False      2016       116                       False
# 1  False  False  False      2016       116                       False
# 2  False  False  False      2017       117                       False
# 3  False  False  False      2017         6                       False
# 4   True  False  False      2016         2                       False
#
#    RegionGroup_N_S_SE_Metropolitan  RegionGroup_W_Metropolitan  \
# 0                             True                       False
# 1                             True                       False
# 2                             True                       False
# 3                             True                       False
# 4                             True                       False
#
#    RegionGroup_W_N_E_Victoria
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False

# %% [markdown]
# Method - dummy

# %%
data = pd.get_dummies(data, columns=['Method'], prefix='Method', drop_first=False)
data.head()
# Out:
#        Suburb           Address  Rooms Type      Price SellerG       Date  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0  Biggin 2016-12-03
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0  Biggin 2016-02-04
# 2  Abbotsford      5 Charles St      3    h  1465000.0  Biggin 2017-03-04
# 3  Abbotsford  40 Federation La      3    h   850000.0  Biggin 2017-03-04
# 4  Abbotsford       55a Park St      4    h  1600000.0  Nelson 2016-06-04
#
#    Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  BuildingArea  \
# 0       2.5      3067         2         1    1     202.0    118.675000
# 1       2.5      3067         2         1    0     156.0     79.000000
# 2       2.5      3067         3         2    0     134.0    150.000000
# 3       2.5      3067         3         2    1      94.0     98.886364
# 4       2.5      3067         3         1    2     120.0    142.000000
#
#    YearBuilt  Lattitude  Longtitude             Regionname  Propertycount  \
# 0       1900   -37.7996    144.9984  Northern Metropolitan           4019
# 1       1900   -37.8079    144.9934  Northern Metropolitan           4019
# 2       1900   -37.8093    144.9944  Northern Metropolitan           4019
# 3       2011   -37.7969    144.9969  Northern Metropolitan           4019
# 4       2014   -37.8072    144.9941  Northern Metropolitan           4019
#
#    Bedroom2_Group_0  Bedroom2_Group_1  Bedroom2_Group_2_3  Bedroom2_Group_4_5  \
# 0             False             False                True               False
# 1             False             False                True               False
# 2             False             False                True               False
# 3             False             False                True               False
# 4             False             False                True               False
#
#    Bedroom2_Group_6_or_more  Car_Category  Car_0  Car_1  Car_2  Car_3  Car_4  \
# 0                     False             1  False   True  False  False  False
# 1                     False             0   True  False  False  False  False
# 2                     False             0   True  False  False  False  False
# 3                     False             1  False   True  False  False  False
# 4                     False             2  False  False   True  False  False
#
#    YearSold  HouseAge  RegionGroup_E_Metropolitan  \
# 0      2016       116                       False
# 1      2016       116                       False
# 2      2017       117                       False
# 3      2017         6                       False
# 4      2016         2                       False
#
#    RegionGroup_N_S_SE_Metropolitan  RegionGroup_W_Metropolitan  \
# 0                             True                       False
# 1                             True                       False
# 2                             True                       False
# 3                             True                       False
# 4                             True                       False
#
#    RegionGroup_W_N_E_Victoria  Method_PI  Method_S  Method_SA  Method_SP  \
# 0                       False      False      True      False      False
# 1                       False      False      True      False      False
# 2                       False      False     False      False       True
# 3                       False       True     False      False      False
# 4                       False      False     False      False      False
#
#    Method_VB
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True

# %% [markdown]
# **Type** - creating dummies
#
# h- house,cottage,villa, semi,terrace; u- unit, duplex; t- townhouse

# %%
type_dummies = pd.get_dummies(data['Type'], prefix='Type', drop_first=False)

data = pd.concat([data, type_dummies], axis=1)

data.head()
# Out:
#        Suburb           Address  Rooms Type      Price SellerG       Date  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0  Biggin 2016-12-03
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0  Biggin 2016-02-04
# 2  Abbotsford      5 Charles St      3    h  1465000.0  Biggin 2017-03-04
# 3  Abbotsford  40 Federation La      3    h   850000.0  Biggin 2017-03-04
# 4  Abbotsford       55a Park St      4    h  1600000.0  Nelson 2016-06-04
#
#    Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  BuildingArea  \
# 0       2.5      3067         2         1    1     202.0    118.675000
# 1       2.5      3067         2         1    0     156.0     79.000000
# 2       2.5      3067         3         2    0     134.0    150.000000
# 3       2.5      3067         3         2    1      94.0     98.886364
# 4       2.5      3067         3         1    2     120.0    142.000000
#
#    YearBuilt  Lattitude  Longtitude             Regionname  Propertycount  \
# 0       1900   -37.7996    144.9984  Northern Metropolitan           4019
# 1       1900   -37.8079    144.9934  Northern Metropolitan           4019
# 2       1900   -37.8093    144.9944  Northern Metropolitan           4019
# 3       2011   -37.7969    144.9969  Northern Metropolitan           4019
# 4       2014   -37.8072    144.9941  Northern Metropolitan           4019
#
#    Bedroom2_Group_0  Bedroom2_Group_1  Bedroom2_Group_2_3  Bedroom2_Group_4_5  \
# 0             False             False                True               False
# 1             False             False                True               False
# 2             False             False                True               False
# 3             False             False                True               False
# 4             False             False                True               False
#
#    Bedroom2_Group_6_or_more  Car_Category  Car_0  Car_1  Car_2  Car_3  Car_4  \
# 0                     False             1  False   True  False  False  False
# 1                     False             0   True  False  False  False  False
# 2                     False             0   True  False  False  False  False
# 3                     False             1  False   True  False  False  False
# 4                     False             2  False  False   True  False  False
#
#    YearSold  HouseAge  RegionGroup_E_Metropolitan  \
# 0      2016       116                       False
# 1      2016       116                       False
# 2      2017       117                       False
# 3      2017         6                       False
# 4      2016         2                       False
#
#    RegionGroup_N_S_SE_Metropolitan  RegionGroup_W_Metropolitan  \
# 0                             True                       False
# 1                             True                       False
# 2                             True                       False
# 3                             True                       False
# 4                             True                       False
#
#    RegionGroup_W_N_E_Victoria  Method_PI  Method_S  Method_SA  Method_SP  \
# 0                       False      False      True      False      False
# 1                       False      False      True      False      False
# 2                       False      False     False      False       True
# 3                       False       True     False      False      False
# 4                       False      False     False      False      False
#
#    Method_VB  Type_h  Type_t  Type_u
# 0      False    True   False   False
# 1      False    True   False   False
# 2      False    True   False   False
# 3      False    True   False   False
# 4       True    True   False   False

# %% [markdown]
# ## Creating a new dataset file with new features

# %%
data.to_csv('After_feature_engineering.csv', index=False)

# %%
new_dataset = pd.read_csv("C:/Users/lasko/Documents/Bocconi/1st semester/Statistics and Probability/Final Report/After_feature_engineering.csv")
new_dataset.head()
# Out:
#        Suburb           Address  Rooms Type      Price SellerG        Date  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0  Biggin  2016-12-03
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0  Biggin  2016-02-04
# 2  Abbotsford      5 Charles St      3    h  1465000.0  Biggin  2017-03-04
# 3  Abbotsford  40 Federation La      3    h   850000.0  Biggin  2017-03-04
# 4  Abbotsford       55a Park St      4    h  1600000.0  Nelson  2016-06-04
#
#    Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  BuildingArea  \
# 0       2.5      3067         2         1    1     202.0    118.675000
# 1       2.5      3067         2         1    0     156.0     79.000000
# 2       2.5      3067         3         2    0     134.0    150.000000
# 3       2.5      3067         3         2    1      94.0     98.886364
# 4       2.5      3067         3         1    2     120.0    142.000000
#
#    YearBuilt  Lattitude  Longtitude             Regionname  Propertycount  \
# 0       1900   -37.7996    144.9984  Northern Metropolitan           4019
# 1       1900   -37.8079    144.9934  Northern Metropolitan           4019
# 2       1900   -37.8093    144.9944  Northern Metropolitan           4019
# 3       2011   -37.7969    144.9969  Northern Metropolitan           4019
# 4       2014   -37.8072    144.9941  Northern Metropolitan           4019
#
#    Bedroom2_Group_0  Bedroom2_Group_1  Bedroom2_Group_2_3  Bedroom2_Group_4_5  \
# 0             False             False                True               False
# 1             False             False                True               False
# 2             False             False                True               False
# 3             False             False                True               False
# 4             False             False                True               False
#
#    Bedroom2_Group_6_or_more  Car_Category  Car_0  Car_1  Car_2  Car_3  Car_4  \
# 0                     False             1  False   True  False  False  False
# 1                     False             0   True  False  False  False  False
# 2                     False             0   True  False  False  False  False
# 3                     False             1  False   True  False  False  False
# 4                     False             2  False  False   True  False  False
#
#    YearSold  HouseAge  RegionGroup_E_Metropolitan  \
# 0      2016       116                       False
# 1      2016       116                       False
# 2      2017       117                       False
# 3      2017         6                       False
# 4      2016         2                       False
#
#    RegionGroup_N_S_SE_Metropolitan  RegionGroup_W_Metropolitan  \
# 0                             True                       False
# 1                             True                       False
# 2                             True                       False
# 3                             True                       False
# 4                             True                       False
#
#    RegionGroup_W_N_E_Victoria  Method_PI  Method_S  Method_SA  Method_SP  \
# 0                       False      False      True      False      False
# 1                       False      False      True      False      False
# 2                       False      False     False      False       True
# 3                       False       True     False      False      False
# 4                       False      False     False      False      False
#
#    Method_VB  Type_h  Type_t  Type_u
# 0      False    True   False   False
# 1      False    True   False   False
# 2      False    True   False   False
# 3      False    True   False   False
# 4       True    True   False   False

# %% [markdown]
# ## Dropping unnecessary columns for the analysis

# %%
columns_to_drop = ['Suburb', 'Address', 'SellerG', 'Date', 'Postcode', 'Lattitude', 'Longtitude', 'Type', 'Bedroom2', 'Car', 'Regionname', 'YearBuilt', 'Car_Category']
new_dataset = new_dataset.drop(columns=columns_to_drop, errors='ignore')

new_dataset.head()
# Out:
#    Rooms      Price  Distance  Bathroom  Landsize  BuildingArea  \
# 0      2  1480000.0       2.5         1     202.0    118.675000
# 1      2  1035000.0       2.5         1     156.0     79.000000
# 2      3  1465000.0       2.5         2     134.0    150.000000
# 3      3   850000.0       2.5         2      94.0     98.886364
# 4      4  1600000.0       2.5         1     120.0    142.000000
#
#    Propertycount  Bedroom2_Group_0  Bedroom2_Group_1  Bedroom2_Group_2_3  \
# 0           4019             False             False                True
# 1           4019             False             False                True
# 2           4019             False             False                True
# 3           4019             False             False                True
# 4           4019             False             False                True
#
#    Bedroom2_Group_4_5  Bedroom2_Group_6_or_more  Car_0  Car_1  Car_2  Car_3  \
# 0               False                     False  False   True  False  False
# 1               False                     False   True  False  False  False
# 2               False                     False   True  False  False  False
# 3               False                     False  False   True  False  False
# 4               False                     False  False  False   True  False
#
#    Car_4  YearSold  HouseAge  RegionGroup_E_Metropolitan  \
# 0  False      2016       116                       False
# 1  False      2016       116                       False
# 2  False      2017       117                       False
# 3  False      2017         6                       False
# 4  False      2016         2                       False
#
#    RegionGroup_N_S_SE_Metropolitan  RegionGroup_W_Metropolitan  \
# 0                             True                       False
# 1                             True                       False
# 2                             True                       False
# 3                             True                       False
# 4                             True                       False
#
#    RegionGroup_W_N_E_Victoria  Method_PI  Method_S  Method_SA  Method_SP  \
# 0                       False      False      True      False      False
# 1                       False      False      True      False      False
# 2                       False      False     False      False       True
# 3                       False       True     False      False      False
# 4                       False      False     False      False      False
#
#    Method_VB  Type_h  Type_t  Type_u
# 0      False    True   False   False
# 1      False    True   False   False
# 2      False    True   False   False
# 3      False    True   False   False
# 4       True    True   False   False

# %% [markdown]
# ## Correlations

# %% [markdown]
# ##### Numerical vs Numerical

# %%
numerical_cols = new_dataset.select_dtypes(include=[np.number]).columns
correlation_matrix = new_dataset[numerical_cols].corr()

# Heatmap of numerical correlations
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", vmin=-1, vmax=1)
plt.title("Correlation Heatmap for Numerical Variables")
plt.show()

# %%
high_corr_pairs = [
    (col1, col2, correlation_matrix.loc[col1, col2])
    for col1 in correlation_matrix.columns
    for col2 in correlation_matrix.columns
    if col1 != col2 and abs(correlation_matrix.loc[col1, col2]) > 0.6
]
high_corr_pairs=pd.DataFrame(high_corr_pairs)
high_corr_pairs
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ##### Categorical vs Categorical

# %%
categorical_cols = new_dataset.select_dtypes(include=["object", "category"]).columns


categorical_corr_optimized = {}
for col1 in categorical_cols:
    for col2 in categorical_cols:
        if col1 != col2:
            contingency_table = pd.crosstab(new_dataset[col1], new_dataset[col2])
            chi2, p, _, _ = chi2_contingency(contingency_table, correction=False)
            if p < 0.05:
                categorical_corr_optimized[(col1, col2)] = p

categorical_corr_optimized
# Out:
# {}

# %% [markdown]
# ##### Numerical vs Categorical

# %%
categorical_vs_numerical_corr_optimized = {}
for cat_col in categorical_cols:
    unique_values = new_dataset[cat_col].nunique()
    if unique_values <= 10: 
        for num_col in numerical_cols:
            anova_p = f_oneway(
                *[new_dataset[new_dataset[cat_col] == category][num_col].dropna()
                  for category in new_dataset[cat_col].unique()]
            ).pvalue
            if anova_p < 0.05:
                categorical_vs_numerical_corr_optimized[(cat_col, num_col)] = anova_p

categorical_vs_numerical_corr_optimized
# Out:
# {}

# %% [markdown]
# ## Training and Test Set

# %%
train_data = new_dataset[new_dataset['YearSold'] == 2016]
test_data = new_dataset[new_dataset['YearSold'] == 2017]

# %% [markdown]
# ## Dropping unnecessary column - YearSold

# %%
columns_to_drop = ['YearSold']
new_dataset = new_dataset.drop(columns=columns_to_drop, errors='ignore')

new_dataset.head()
# Out:
#    Rooms      Price  Distance  Bathroom  Landsize  BuildingArea  \
# 0      2  1480000.0       2.5         1     202.0    118.675000
# 1      2  1035000.0       2.5         1     156.0     79.000000
# 2      3  1465000.0       2.5         2     134.0    150.000000
# 3      3   850000.0       2.5         2      94.0     98.886364
# 4      4  1600000.0       2.5         1     120.0    142.000000
#
#    Propertycount  Bedroom2_Group_0  Bedroom2_Group_1  Bedroom2_Group_2_3  \
# 0           4019             False             False                True
# 1           4019             False             False                True
# 2           4019             False             False                True
# 3           4019             False             False                True
# 4           4019             False             False                True
#
#    Bedroom2_Group_4_5  Bedroom2_Group_6_or_more  Car_0  Car_1  Car_2  Car_3  \
# 0               False                     False  False   True  False  False
# 1               False                     False   True  False  False  False
# 2               False                     False   True  False  False  False
# 3               False                     False  False   True  False  False
# 4               False                     False  False  False   True  False
#
#    Car_4  HouseAge  RegionGroup_E_Metropolitan  \
# 0  False       116                       False
# 1  False       116                       False
# 2  False       117                       False
# 3  False         6                       False
# 4  False         2                       False
#
#    RegionGroup_N_S_SE_Metropolitan  RegionGroup_W_Metropolitan  \
# 0                             True                       False
# 1                             True                       False
# 2                             True                       False
# 3                             True                       False
# 4                             True                       False
#
#    RegionGroup_W_N_E_Victoria  Method_PI  Method_S  Method_SA  Method_SP  \
# 0                       False      False      True      False      False
# 1                       False      False      True      False      False
# 2                       False      False     False      False       True
# 3                       False       True     False      False      False
# 4                       False      False     False      False      False
#
#    Method_VB  Type_h  Type_t  Type_u
# 0      False    True   False   False
# 1      False    True   False   False
# 2      False    True   False   False
# 3      False    True   False   False
# 4       True    True   False   False

# %% [markdown]
# ## Metrics

# %%
metrics_df = pd.DataFrame(columns=['Model', 'MSE', 'RMSE', 'MAE'])

# %% [markdown]
# ## Model 1 - basic features

# %% [markdown]
# Training

# %%
model = smf.ols('Price ~ Distance + Bathroom + BuildingArea + HouseAge', train_data).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.433
# Model:                            OLS   Adj. R-squared:                  0.433
# Method:                 Least Squares   F-statistic:                     1187.
# Date:                Tue, 07 Jan 2025   Prob (F-statistic):               0.00
# Time:                        03:41:37   Log-Likelihood:                -90296.
# No. Observations:                6225   AIC:                         1.806e+05
# Df Residuals:                    6220   BIC:                         1.806e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept     1.404e+05   2.36e+04      5.937      0.000     9.4e+04    1.87e+05
# Distance      -2.61e+04   1766.399    -14.775      0.000   -2.96e+04   -2.26e+04
# Bathroom      3.871e+05   1.01e+04     38.389      0.000    3.67e+05    4.07e+05
# BuildingArea  2579.5402     82.417     31.299      0.000    2417.975    2741.105
# HouseAge      3908.2963    168.255     23.228      0.000    3578.458    4238.134
# ==============================================================================
# Omnibus:                     2161.924   Durbin-Watson:                   1.584
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            46110.009
# Skew:                           1.143   Prob(JB):                         0.00
# Kurtosis:                      16.136   Cond. No.                         678.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Test

# %%
model_name = "Model 1"
predictions = model.predict(test_data)
mse = mean_squared_error(test_data['Price'], predictions)
rmse = np.sqrt(mse)
mae = mean_absolute_error(test_data['Price'], predictions)
print(f"Root Mean Squared Error: {rmse}")
print(f"Mean Absolute Error: {mae}")

metrics_df = pd.concat([
    metrics_df,
    pd.DataFrame({'Model': [model_name], 'MSE': [mse], 'RMSE': [rmse], 'MAE': [mae]})
], ignore_index=True)

metrics_df
# Out:
# Root Mean Squared Error: 527914.5701986082
# Mean Absolute Error: 335634.22139692464
# C:\Users\lasko\AppData\Local\Temp\ipykernel_31128\957269323.py:9: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   metrics_df = pd.concat([
#      Model           MSE           RMSE            MAE
# 0  Model 1  2.786938e+11  527914.570199  335634.221397

# %%
plt.figure(figsize=(10, 6))
max_price = max(max(test_data['Price']), max(predictions))
min_price = min(min(test_data['Price']), min(predictions)) 
plt.plot([min_price, max_price], [min_price, max_price], color='red', linestyle='--', label='Perfect Prediction')
plt.scatter(test_data['Price'], predictions, alpha=0.7, color='blue', label='Predicted vs Actual')
plt.title('Actual vs Predicted Prices')
plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ##### HELPER FUNCTION - NAMES OF ALL THE COLUMNS

# %%
concatenated_columns = ' + '.join([col for col in new_dataset.columns if col != 'Price'])
concatenated_columns
# Out:
# 'Rooms + Distance + Bathroom + Landsize + BuildingArea + Propertycount + Bedroom2_Group_0 + Bedroom2_Group_1 + Bedroom2_Group_2_3 + Bedroom2_Group_4_5 + Bedroom2_Group_6_or_more + Car_0 + Car_1 + Car_2 + Car_3 + Car_4 + HouseAge + RegionGroup_E_Metropolitan + RegionGroup_N_S_SE_Metropolitan + RegionGroup_W_Metropolitan + RegionGroup_W_N_E_Victoria + Method_PI + Method_S + Method_SA + Method_SP + Method_VB + Type_h + Type_t + Type_u'

# %% [markdown]
# ## Multicollinearity
# Choosing dummies as a benchmark to exclude from the model
# - RegionGroup_W_N_E_Victoria
# - Bedroom2_Group_0
# - Car_0
# - Method_S
# - Type_h

# %% [markdown]
# ## Model 2 - all features, no interactions

# %% [markdown]
# Training

# %%
model = smf.ols('Price ~ Rooms + Distance + Bathroom + Landsize + BuildingArea + Bedroom2_Group_1 + Bedroom2_Group_2_3 + Bedroom2_Group_4_5 + Bedroom2_Group_6_or_more + Car_1 + Car_2 + Car_3 + Car_4 + HouseAge + RegionGroup_E_Metropolitan + RegionGroup_N_S_SE_Metropolitan + RegionGroup_W_Metropolitan + Method_PI + Method_SA + Method_SP + Method_VB + Type_t + Type_u', train_data).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.583
# Model:                            OLS   Adj. R-squared:                  0.582
# Method:                 Least Squares   F-statistic:                     394.2
# Date:                Tue, 07 Jan 2025   Prob (F-statistic):               0.00
# Time:                        03:41:38   Log-Likelihood:                -89338.
# No. Observations:                6225   AIC:                         1.787e+05
# Df Residuals:                    6202   BIC:                         1.789e+05
# Df Model:                          22
# Covariance Type:            nonrobust
# ===========================================================================================================
#                                               coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# Intercept                                3.944e+05   1.02e+05      3.859      0.000    1.94e+05    5.95e+05
# Bedroom2_Group_1[T.True]                -2.759e+05   1.34e+05     -2.055      0.040   -5.39e+05   -1.27e+04
# Bedroom2_Group_2_3[T.True]              -1.885e+05   1.32e+05     -1.433      0.152   -4.46e+05    6.94e+04
# Bedroom2_Group_4_5[T.True]              -1.222e+05   1.33e+05     -0.921      0.357   -3.82e+05    1.38e+05
# Bedroom2_Group_6_or_more[T.True]        -4.396e+05   1.56e+05     -2.824      0.005   -7.45e+05   -1.34e+05
# Car_1[T.True]                           -1.528e+04   2.22e+04     -0.689      0.491   -5.88e+04    2.82e+04
# Car_2[T.True]                            6.587e+04   2.36e+04      2.794      0.005    1.97e+04    1.12e+05
# Car_3[T.True]                            9.248e+04   2.94e+04      3.146      0.002    3.48e+04     1.5e+05
# Car_4[T.True]                             4.01e+04   6.79e+04      0.591      0.555   -9.29e+04    1.73e+05
# RegionGroup_E_Metropolitan[T.True]       1.132e+05   3.73e+04      3.032      0.002       4e+04    1.86e+05
# RegionGroup_N_S_SE_Metropolitan[T.True]  2.816e+05   3.46e+04      8.137      0.000    2.14e+05    3.49e+05
# RegionGroup_W_Metropolitan[T.True]       -388.8265   3.56e+04     -0.011      0.991   -7.01e+04    6.93e+04
# Method_PI[T.True]                       -9.819e+04   1.64e+04     -5.994      0.000    -1.3e+05   -6.61e+04
# Method_SA[T.True]                       -7013.1362   8.68e+04     -0.081      0.936   -1.77e+05    1.63e+05
# Method_SP[T.True]                       -7.858e+04   1.66e+04     -4.723      0.000   -1.11e+05    -4.6e+04
# Method_VB[T.True]                       -5.102e+04    1.9e+04     -2.692      0.007   -8.82e+04   -1.39e+04
# Type_t[T.True]                          -1.559e+05   2.13e+04     -7.323      0.000   -1.98e+05   -1.14e+05
# Type_u[T.True]                          -2.201e+05   1.71e+04    -12.861      0.000   -2.54e+05   -1.87e+05
# Rooms                                    1.056e+05   1.15e+04      9.167      0.000     8.3e+04    1.28e+05
# Distance                                 -4.72e+04   1759.408    -26.829      0.000   -5.07e+04   -4.38e+04
# Bathroom                                 2.656e+05   1.05e+04     25.275      0.000    2.45e+05    2.86e+05
# Landsize                                  475.8517     28.416     16.746      0.000     420.146     531.558
# BuildingArea                             1044.2928     80.144     13.030      0.000     887.182    1201.403
# HouseAge                                 1854.7103    156.791     11.829      0.000    1547.345    2162.075
# ==============================================================================
# Omnibus:                     2606.728   Durbin-Watson:                   1.424
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            28747.943
# Skew:                           1.697   Prob(JB):                         0.00
# Kurtosis:                      12.966   Cond. No.                     2.32e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.8e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# Test

# %%
model_name = "Model 2"
predictions = model.predict(test_data)
mse = mean_squared_error(test_data['Price'], predictions)
rmse = np.sqrt(mse)
mae = mean_absolute_error(test_data['Price'], predictions)
print(f"Root Mean Squared Error: {rmse}")
print(f"Mean Absolute Error: {mae}")

metrics_df = pd.concat([
    metrics_df,
    pd.DataFrame({'Model': [model_name], 'MSE': [mse], 'RMSE': [rmse], 'MAE': [mae]})
], ignore_index=True)

metrics_df
# Out:
# Root Mean Squared Error: 453177.0408647971
# Mean Absolute Error: 315777.48225494364
#      Model           MSE           RMSE            MAE
# 0  Model 1  2.786938e+11  527914.570199  335634.221397
# 1  Model 2  2.053694e+11  453177.040865  315777.482255

# %%
plt.figure(figsize=(10, 6))
max_price = max(max(test_data['Price']), max(predictions))
min_price = min(min(test_data['Price']), min(predictions)) 
plt.plot([min_price, max_price], [min_price, max_price], color='red', linestyle='--', label='Perfect Prediction')
plt.scatter(test_data['Price'], predictions, alpha=0.7, color='blue', label='Predicted vs Actual')
plt.title('Actual vs Predicted Prices')
plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Ideas for interactions
# - Rooms * BuildingArea
# - BuildingArea * RegionGroup
# - Type * RegionGroup
# - Method * RegionGroup

# %% [markdown]
# ## Model 3 - all features, with interactions
# - BuildingArea * RegionGroup

# %% [markdown]
# Training

# %%
model = smf.ols('Price ~ Rooms + Distance + Bathroom + Landsize + Bedroom2_Group_1 + Bedroom2_Group_2_3 + Bedroom2_Group_4_5 + Bedroom2_Group_6_or_more + Car_1 + Car_2 + Car_3 + Car_4 + HouseAge + BuildingArea*RegionGroup_E_Metropolitan + BuildingArea*RegionGroup_N_S_SE_Metropolitan + BuildingArea*RegionGroup_W_Metropolitan + Method_PI + Method_SA + Method_SP + Method_VB + Type_t + Type_u', train_data).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.590
# Model:                            OLS   Adj. R-squared:                  0.589
# Method:                 Least Squares   F-statistic:                     371.9
# Date:                Tue, 07 Jan 2025   Prob (F-statistic):               0.00
# Time:                        03:41:38   Log-Likelihood:                -89285.
# No. Observations:                6225   AIC:                         1.786e+05
# Df Residuals:                    6200   BIC:                         1.788e+05
# Df Model:                          24
# Covariance Type:            nonrobust
# ========================================================================================================================
#                                                            coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------
# Intercept                                             4.978e+05   1.02e+05      4.873      0.000    2.98e+05    6.98e+05
# Bedroom2_Group_1[T.True]                             -2.734e+05   1.33e+05     -2.053      0.040   -5.34e+05   -1.24e+04
# Bedroom2_Group_2_3[T.True]                           -1.987e+05    1.3e+05     -1.523      0.128   -4.54e+05     5.7e+04
# Bedroom2_Group_4_5[T.True]                           -1.253e+05   1.32e+05     -0.953      0.341   -3.83e+05    1.33e+05
# Bedroom2_Group_6_or_more[T.True]                     -4.397e+05   1.54e+05     -2.849      0.004   -7.42e+05   -1.37e+05
# Car_1[T.True]                                        -1.934e+04    2.2e+04     -0.879      0.379   -6.25e+04    2.38e+04
# Car_2[T.True]                                         6.509e+04   2.34e+04      2.783      0.005    1.92e+04    1.11e+05
# Car_3[T.True]                                         9.264e+04   2.92e+04      3.177      0.001    3.55e+04     1.5e+05
# Car_4[T.True]                                         8.071e+04   6.75e+04      1.195      0.232   -5.16e+04    2.13e+05
# RegionGroup_E_Metropolitan[T.True]                    2.113e+05   4.97e+04      4.255      0.000    1.14e+05    3.09e+05
# RegionGroup_N_S_SE_Metropolitan[T.True]               1.552e+05    3.7e+04      4.199      0.000    8.27e+04    2.28e+05
# RegionGroup_W_Metropolitan[T.True]                    1.313e+05   4.14e+04      3.168      0.002    5.01e+04    2.13e+05
# Method_PI[T.True]                                    -1.003e+05   1.62e+04     -6.175      0.000   -1.32e+05   -6.85e+04
# Method_SA[T.True]                                    -7079.1442    8.6e+04     -0.082      0.934   -1.76e+05    1.62e+05
# Method_SP[T.True]                                    -8.082e+04   1.65e+04     -4.897      0.000   -1.13e+05   -4.85e+04
# Method_VB[T.True]                                    -5.817e+04   1.88e+04     -3.093      0.002    -9.5e+04   -2.13e+04
# Type_t[T.True]                                       -1.624e+05   2.11e+04     -7.688      0.000   -2.04e+05   -1.21e+05
# Type_u[T.True]                                       -2.223e+05    1.7e+04    -13.097      0.000   -2.56e+05   -1.89e+05
# Rooms                                                 1.085e+05   1.14e+04      9.497      0.000    8.61e+04    1.31e+05
# Distance                                             -4.833e+04   1748.284    -27.647      0.000   -5.18e+04   -4.49e+04
# Bathroom                                              2.689e+05   1.04e+04     25.777      0.000    2.48e+05    2.89e+05
# Landsize                                               480.0486     28.183     17.033      0.000     424.800     535.297
# HouseAge                                              1745.8928    155.843     11.203      0.000    1440.387    2051.398
# BuildingArea                                           165.0458     92.952      1.776      0.076     -17.173     347.265
# BuildingArea:RegionGroup_E_Metropolitan[T.True]       -320.1884    209.200     -1.531      0.126    -730.292      89.916
# BuildingArea:RegionGroup_N_S_SE_Metropolitan[T.True]  1140.2442     96.548     11.810      0.000     950.978    1329.511
# BuildingArea:RegionGroup_W_Metropolitan[T.True]       -655.0100    151.048     -4.336      0.000    -951.116    -358.904
# ==============================================================================
# Omnibus:                     2487.552   Durbin-Watson:                   1.424
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            30050.255
# Skew:                           1.570   Prob(JB):                         0.00
# Kurtosis:                      13.296   Cond. No.                     8.85e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.01e-23. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# Test

# %%
model_name = "Model 3"
predictions = model.predict(test_data)
mse = mean_squared_error(test_data['Price'], predictions)
rmse = np.sqrt(mse)
mae = mean_absolute_error(test_data['Price'], predictions)
print(f"Root Mean Squared Error: {rmse}")
print(f"Mean Absolute Error: {mae}")

metrics_df = pd.concat([
    metrics_df,
    pd.DataFrame({'Model': [model_name], 'MSE': [mse], 'RMSE': [rmse], 'MAE': [mae]})
], ignore_index=True)

metrics_df
# Out:
# Root Mean Squared Error: 444700.58554075065
# Mean Absolute Error: 313349.9221569042
#      Model           MSE           RMSE            MAE
# 0  Model 1  2.786938e+11  527914.570199  335634.221397
# 1  Model 2  2.053694e+11  453177.040865  315777.482255
# 2  Model 3  1.977586e+11  444700.585541  313349.922157

# %%
plt.figure(figsize=(10, 6))
max_price = max(max(test_data['Price']), max(predictions))
min_price = min(min(test_data['Price']), min(predictions)) 
plt.plot([min_price, max_price], [min_price, max_price], color='red', linestyle='--', label='Perfect Prediction')
plt.scatter(test_data['Price'], predictions, alpha=0.7, color='blue', label='Predicted vs Actual')
plt.title('Actual vs Predicted Prices')
plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Model 4 - all features, with interactions
# - BuildingArea * RegionGroup
# - Rooms * BuildingArea

# %% [markdown]
# Training

# %%
model = smf.ols('Price ~ Distance + Bathroom + Landsize + Rooms*BuildingArea + Bedroom2_Group_1 + Bedroom2_Group_2_3 + Bedroom2_Group_4_5 + Bedroom2_Group_6_or_more + Car_1 + Car_2 + Car_3 + Car_4 + HouseAge + BuildingArea*RegionGroup_E_Metropolitan + BuildingArea*RegionGroup_N_S_SE_Metropolitan + BuildingArea*RegionGroup_W_Metropolitan + Method_PI + Method_SA + Method_SP + Method_VB + Type_t + Type_u', train_data).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.590
# Model:                            OLS   Adj. R-squared:                  0.589
# Method:                 Least Squares   F-statistic:                     357.3
# Date:                Tue, 07 Jan 2025   Prob (F-statistic):               0.00
# Time:                        03:41:38   Log-Likelihood:                -89284.
# No. Observations:                6225   AIC:                         1.786e+05
# Df Residuals:                    6199   BIC:                         1.788e+05
# Df Model:                          25
# Covariance Type:            nonrobust
# ========================================================================================================================
#                                                            coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------
# Intercept                                             5.345e+05   1.04e+05      5.134      0.000     3.3e+05    7.39e+05
# Bedroom2_Group_1[T.True]                             -2.856e+05   1.33e+05     -2.143      0.032   -5.47e+05   -2.43e+04
# Bedroom2_Group_2_3[T.True]                            -1.96e+05    1.3e+05     -1.503      0.133   -4.52e+05    5.97e+04
# Bedroom2_Group_4_5[T.True]                           -1.265e+05   1.32e+05     -0.962      0.336   -3.84e+05    1.31e+05
# Bedroom2_Group_6_or_more[T.True]                     -4.544e+05   1.55e+05     -2.941      0.003   -7.57e+05   -1.51e+05
# Car_1[T.True]                                        -1.937e+04    2.2e+04     -0.881      0.379   -6.25e+04    2.38e+04
# Car_2[T.True]                                         6.607e+04   2.34e+04      2.824      0.005    2.02e+04    1.12e+05
# Car_3[T.True]                                         9.191e+04   2.92e+04      3.152      0.002    3.47e+04    1.49e+05
# Car_4[T.True]                                         7.933e+04   6.75e+04      1.175      0.240    -5.3e+04    2.12e+05
# RegionGroup_E_Metropolitan[T.True]                    2.241e+05   5.01e+04      4.469      0.000    1.26e+05    3.22e+05
# RegionGroup_N_S_SE_Metropolitan[T.True]                 1.7e+05   3.78e+04      4.494      0.000    9.59e+04    2.44e+05
# RegionGroup_W_Metropolitan[T.True]                    1.404e+05   4.17e+04      3.363      0.001    5.86e+04    2.22e+05
# Method_PI[T.True]                                    -1.013e+05   1.63e+04     -6.233      0.000   -1.33e+05   -6.94e+04
# Method_SA[T.True]                                    -5778.1430    8.6e+04     -0.067      0.946   -1.74e+05    1.63e+05
# Method_SP[T.True]                                    -8.143e+04   1.65e+04     -4.934      0.000   -1.14e+05   -4.91e+04
# Method_VB[T.True]                                    -5.822e+04   1.88e+04     -3.096      0.002   -9.51e+04   -2.14e+04
# Type_t[T.True]                                       -1.615e+05   2.11e+04     -7.642      0.000   -2.03e+05    -1.2e+05
# Type_u[T.True]                                       -2.282e+05   1.73e+04    -13.208      0.000   -2.62e+05   -1.94e+05
# Distance                                             -4.822e+04   1748.996    -27.573      0.000   -5.17e+04   -4.48e+04
# Bathroom                                               2.69e+05   1.04e+04     25.792      0.000    2.49e+05    2.89e+05
# Landsize                                               489.0122     28.605     17.095      0.000     432.936     545.089
# Rooms                                                 9.275e+04   1.43e+04      6.465      0.000    6.46e+04    1.21e+05
# BuildingArea                                          -132.8987    188.322     -0.706      0.480    -502.075     236.278
# BuildingArea:RegionGroup_E_Metropolitan[T.True]       -425.9600    217.093     -1.962      0.050    -851.537      -0.383
# BuildingArea:RegionGroup_N_S_SE_Metropolitan[T.True]  1022.0161    116.372      8.782      0.000     793.888    1250.145
# BuildingArea:RegionGroup_W_Metropolitan[T.True]       -728.9548    156.395     -4.661      0.000   -1035.544    -422.366
# Rooms:BuildingArea                                     107.6284     59.168      1.819      0.069      -8.362     223.618
# HouseAge                                              1743.6966    155.818     11.191      0.000    1438.239    2049.154
# ==============================================================================
# Omnibus:                     2492.016   Durbin-Watson:                   1.423
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            31429.588
# Skew:                           1.560   Prob(JB):                         0.00
# Kurtosis:                      13.557   Cond. No.                     1.08e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.99e-23. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# Test

# %%
model_name = "Model 4"
predictions = model.predict(test_data)
mse = mean_squared_error(test_data['Price'], predictions)
rmse = np.sqrt(mse)
mae = mean_absolute_error(test_data['Price'], predictions)
print(f"Root Mean Squared Error: {rmse}")
print(f"Mean Absolute Error: {mae}")

metrics_df = pd.concat([
    metrics_df,
    pd.DataFrame({'Model': [model_name], 'MSE': [mse], 'RMSE': [rmse], 'MAE': [mae]})
], ignore_index=True)

metrics_df
# Out:
# Root Mean Squared Error: 444477.71110379184
# Mean Absolute Error: 313331.5183022104
#      Model           MSE           RMSE            MAE
# 0  Model 1  2.786938e+11  527914.570199  335634.221397
# 1  Model 2  2.053694e+11  453177.040865  315777.482255
# 2  Model 3  1.977586e+11  444700.585541  313349.922157
# 3  Model 4  1.975604e+11  444477.711104  313331.518302

# %%
plt.figure(figsize=(10, 6))
max_price = max(max(test_data['Price']), max(predictions))
min_price = min(min(test_data['Price']), min(predictions)) 
plt.plot([min_price, max_price], [min_price, max_price], color='red', linestyle='--', label='Perfect Prediction')
plt.scatter(test_data['Price'], predictions, alpha=0.7, color='blue', label='Predicted vs Actual')
plt.title('Actual vs Predicted Prices')
plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Model 5 - all features, with interactions
# - BuildingArea * RegionGroup
# - Type * RegionGroup

# %% [markdown]
# Training

# %%
model = smf.ols('Price ~ Distance + Bathroom + Landsize + Rooms + Bedroom2_Group_1 + Bedroom2_Group_2_3 + Bedroom2_Group_4_5 + Bedroom2_Group_6_or_more + Car_1 + Car_2 + Car_3 + Car_4 + HouseAge + BuildingArea*RegionGroup_E_Metropolitan + BuildingArea*RegionGroup_N_S_SE_Metropolitan + BuildingArea*RegionGroup_W_Metropolitan + Type_t*RegionGroup_E_Metropolitan + Type_t*RegionGroup_N_S_SE_Metropolitan + Type_t*RegionGroup_W_Metropolitan + Type_u*RegionGroup_E_Metropolitan + Type_u*RegionGroup_N_S_SE_Metropolitan + Type_u*RegionGroup_W_Metropolitan +Method_PI + Method_SA + Method_SP + Method_VB', train_data).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.594
# Model:                            OLS   Adj. R-squared:                  0.592
# Method:                 Least Squares   F-statistic:                     323.5
# Date:                Tue, 07 Jan 2025   Prob (F-statistic):               0.00
# Time:                        03:41:38   Log-Likelihood:                -89257.
# No. Observations:                6225   AIC:                         1.786e+05
# Df Residuals:                    6196   BIC:                         1.788e+05
# Df Model:                          28
# Covariance Type:            nonrobust
# ==========================================================================================================================
#                                                              coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------
# Intercept                                               4.623e+05   1.02e+05      4.537      0.000    2.63e+05    6.62e+05
# Bedroom2_Group_1[T.True]                                -2.71e+05   1.33e+05     -2.044      0.041   -5.31e+05   -1.11e+04
# Bedroom2_Group_2_3[T.True]                             -2.076e+05    1.3e+05     -1.598      0.110   -4.62e+05    4.71e+04
# Bedroom2_Group_4_5[T.True]                             -1.359e+05   1.31e+05     -1.037      0.300   -3.93e+05    1.21e+05
# Bedroom2_Group_6_or_more[T.True]                       -4.536e+05   1.54e+05     -2.950      0.003   -7.55e+05   -1.52e+05
# Car_1[T.True]                                          -1.317e+04   2.19e+04     -0.600      0.548   -5.62e+04    2.98e+04
# Car_2[T.True]                                           7.157e+04   2.33e+04      3.070      0.002    2.59e+04    1.17e+05
# Car_3[T.True]                                           9.903e+04   2.91e+04      3.407      0.001    4.21e+04    1.56e+05
# Car_4[T.True]                                           8.616e+04   6.73e+04      1.281      0.200   -4.57e+04    2.18e+05
# RegionGroup_E_Metropolitan[T.True]                       1.38e+05   5.45e+04      2.532      0.011    3.12e+04    2.45e+05
# RegionGroup_N_S_SE_Metropolitan[T.True]                 2.356e+05   3.85e+04      6.121      0.000     1.6e+05    3.11e+05
# RegionGroup_W_Metropolitan[T.True]                      8.868e+04    4.4e+04      2.016      0.044    2456.654    1.75e+05
# Type_t[T.True]                                         -7.652e+04   2.26e+04     -3.385      0.001   -1.21e+05   -3.22e+04
# Type_u[T.True]                                         -8.686e+04   1.81e+04     -4.810      0.000   -1.22e+05   -5.15e+04
# Method_PI[T.True]                                      -9.851e+04   1.62e+04     -6.087      0.000    -1.3e+05   -6.68e+04
# Method_SA[T.True]                                      -2473.9988   8.57e+04     -0.029      0.977    -1.7e+05    1.65e+05
# Method_SP[T.True]                                      -7.853e+04   1.64e+04     -4.776      0.000   -1.11e+05   -4.63e+04
# Method_VB[T.True]                                      -5.902e+04   1.87e+04     -3.151      0.002   -9.57e+04   -2.23e+04
# Type_t[T.True]:RegionGroup_E_Metropolitan[T.True]       6.939e+04   5.61e+04      1.237      0.216   -4.06e+04    1.79e+05
# Type_t[T.True]:RegionGroup_N_S_SE_Metropolitan[T.True]   -1.2e+05    2.7e+04     -4.449      0.000   -1.73e+05   -6.71e+04
# Type_t[T.True]:RegionGroup_W_Metropolitan[T.True]      -2.592e+04   3.53e+04     -0.734      0.463   -9.51e+04    4.33e+04
# Type_u[T.True]:RegionGroup_E_Metropolitan[T.True]       6.756e+04   4.23e+04      1.596      0.110   -1.54e+04    1.51e+05
# Type_u[T.True]:RegionGroup_N_S_SE_Metropolitan[T.True] -1.914e+05   2.01e+04     -9.532      0.000   -2.31e+05   -1.52e+05
# Type_u[T.True]:RegionGroup_W_Metropolitan[T.True]       3.702e+04   2.89e+04      1.282      0.200   -1.96e+04    9.36e+04
# Distance                                               -4.894e+04   1744.096    -28.062      0.000   -5.24e+04   -4.55e+04
# Bathroom                                                2.668e+05   1.04e+04     25.666      0.000    2.46e+05    2.87e+05
# Landsize                                                 491.9449     28.141     17.481      0.000     436.778     547.112
# Rooms                                                   1.069e+05   1.14e+04      9.387      0.000    8.46e+04    1.29e+05
# HouseAge                                                1708.3863    155.346     10.997      0.000    1403.854    2012.918
# BuildingArea                                             364.0012     96.986      3.753      0.000     173.875     554.127
# BuildingArea:RegionGroup_E_Metropolitan[T.True]          -35.5662    227.072     -0.157      0.876    -480.706     409.574
# BuildingArea:RegionGroup_N_S_SE_Metropolitan[T.True]     845.1063    104.586      8.081      0.000     640.082    1050.131
# BuildingArea:RegionGroup_W_Metropolitan[T.True]         -445.5389    163.828     -2.720      0.007    -766.699    -124.378
# ==============================================================================
# Omnibus:                     2512.919   Durbin-Watson:                   1.415
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            29701.621
# Skew:                           1.597   Prob(JB):                         0.00
# Kurtosis:                      13.213   Cond. No.                     1.19e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.12e-23. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# Test

# %%
model_name = "Model 5"
predictions = model.predict(test_data)
mse = mean_squared_error(test_data['Price'], predictions)
rmse = np.sqrt(mse)
mae = mean_absolute_error(test_data['Price'], predictions)
print(f"Root Mean Squared Error: {rmse}")
print(f"Mean Absolute Error: {mae}")

metrics_df = pd.concat([
    metrics_df,
    pd.DataFrame({'Model': [model_name], 'MSE': [mse], 'RMSE': [rmse], 'MAE': [mae]})
], ignore_index=True)

metrics_df
# Out:
# Root Mean Squared Error: 445108.4958342022
# Mean Absolute Error: 313353.6172887406
#      Model           MSE           RMSE            MAE
# 0  Model 1  2.786938e+11  527914.570199  335634.221397
# 1  Model 2  2.053694e+11  453177.040865  315777.482255
# 2  Model 3  1.977586e+11  444700.585541  313349.922157
# 3  Model 4  1.975604e+11  444477.711104  313331.518302
# 4  Model 5  1.981216e+11  445108.495834  313353.617289

# %%
plt.figure(figsize=(10, 6))
max_price = max(max(test_data['Price']), max(predictions))
min_price = min(min(test_data['Price']), min(predictions)) 
plt.plot([min_price, max_price], [min_price, max_price], color='red', linestyle='--', label='Perfect Prediction')
plt.scatter(test_data['Price'], predictions, alpha=0.7, color='blue', label='Predicted vs Actual')
plt.title('Actual vs Predicted Prices')
plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Model 6 - all features, with interactions
# - BuildingArea * RegionGroup
# - Type * RegionGroup
# - Bathroom * Bedroom2_Group

# %% [markdown]
# Training

# %%
model = smf.ols('Price ~ Distance + Landsize + Rooms + Bathroom*Bedroom2_Group_1 + Bathroom*Bedroom2_Group_2_3 + Bathroom*Bedroom2_Group_4_5 + Bathroom*Bedroom2_Group_6_or_more + Car_1 + Car_2 + Car_3 + Car_4 + HouseAge + BuildingArea*RegionGroup_E_Metropolitan + BuildingArea*RegionGroup_N_S_SE_Metropolitan + BuildingArea*RegionGroup_W_Metropolitan + Type_t*RegionGroup_E_Metropolitan + Type_t*RegionGroup_N_S_SE_Metropolitan + Type_t*RegionGroup_W_Metropolitan + Type_u*RegionGroup_E_Metropolitan + Type_u*RegionGroup_N_S_SE_Metropolitan + Type_u*RegionGroup_W_Metropolitan +Method_PI + Method_SA + Method_SP + Method_VB', train_data).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.597
# Model:                            OLS   Adj. R-squared:                  0.595
# Method:                 Least Squares   F-statistic:                     287.0
# Date:                Tue, 07 Jan 2025   Prob (F-statistic):               0.00
# Time:                        03:41:39   Log-Likelihood:                -89230.
# No. Observations:                6225   AIC:                         1.785e+05
# Df Residuals:                    6192   BIC:                         1.787e+05
# Df Model:                          32
# Covariance Type:            nonrobust
# ==========================================================================================================================
#                                                              coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------
# Intercept                                                4.44e+05   1.61e+05      2.765      0.006    1.29e+05    7.59e+05
# Bedroom2_Group_1[T.True]                               -4.124e+05   2.44e+05     -1.687      0.092   -8.92e+05    6.68e+04
# Bedroom2_Group_2_3[T.True]                             -1.309e+05   2.12e+05     -0.618      0.537   -5.46e+05    2.84e+05
# Bedroom2_Group_4_5[T.True]                             -3.269e+05   2.15e+05     -1.521      0.128   -7.48e+05    9.43e+04
# Bedroom2_Group_6_or_more[T.True]                       -1.054e+05   3.26e+05     -0.323      0.747   -7.45e+05    5.34e+05
# Car_1[T.True]                                          -5420.9609   2.19e+04     -0.247      0.805   -4.84e+04    3.76e+04
# Car_2[T.True]                                           8.324e+04   2.33e+04      3.571      0.000    3.75e+04    1.29e+05
# Car_3[T.True]                                            1.06e+05    2.9e+04      3.657      0.000    4.92e+04    1.63e+05
# Car_4[T.True]                                           7.926e+04    6.7e+04      1.183      0.237   -5.21e+04    2.11e+05
# RegionGroup_E_Metropolitan[T.True]                      1.328e+05   6.84e+04      1.943      0.052   -1204.613    2.67e+05
# RegionGroup_N_S_SE_Metropolitan[T.True]                 2.288e+05   5.65e+04      4.052      0.000    1.18e+05    3.39e+05
# RegionGroup_W_Metropolitan[T.True]                      8.248e+04   6.04e+04      1.366      0.172   -3.59e+04    2.01e+05
# Type_t[T.True]                                          -6.88e+04   2.26e+04     -3.051      0.002   -1.13e+05   -2.46e+04
# Type_u[T.True]                                         -9.074e+04    1.8e+04     -5.040      0.000   -1.26e+05   -5.55e+04
# Method_PI[T.True]                                      -1.006e+05   1.61e+04     -6.239      0.000   -1.32e+05    -6.9e+04
# Method_SA[T.True]                                      -1954.6795   8.53e+04     -0.023      0.982   -1.69e+05    1.65e+05
# Method_SP[T.True]                                       -7.87e+04   1.64e+04     -4.805      0.000   -1.11e+05   -4.66e+04
# Method_VB[T.True]                                      -6.096e+04   1.87e+04     -3.265      0.001   -9.76e+04   -2.44e+04
# Type_t[T.True]:RegionGroup_E_Metropolitan[T.True]        7.12e+04   5.59e+04      1.274      0.203   -3.84e+04    1.81e+05
# Type_t[T.True]:RegionGroup_N_S_SE_Metropolitan[T.True] -1.156e+05   2.69e+04     -4.299      0.000   -1.68e+05   -6.29e+04
# Type_t[T.True]:RegionGroup_W_Metropolitan[T.True]      -2.445e+04   3.52e+04     -0.695      0.487   -9.34e+04    4.45e+04
# Type_u[T.True]:RegionGroup_E_Metropolitan[T.True]        6.86e+04   4.22e+04      1.627      0.104    -1.4e+04    1.51e+05
# Type_u[T.True]:RegionGroup_N_S_SE_Metropolitan[T.True] -1.921e+05      2e+04     -9.602      0.000   -2.31e+05   -1.53e+05
# Type_u[T.True]:RegionGroup_W_Metropolitan[T.True]       3.281e+04   2.88e+04      1.140      0.254   -2.36e+04    8.92e+04
# Distance                                               -4.941e+04   1739.401    -28.408      0.000   -5.28e+04    -4.6e+04
# Landsize                                                 484.1900     28.058     17.256      0.000     429.186     539.194
# Rooms                                                   1.134e+05   1.14e+04      9.937      0.000     9.1e+04    1.36e+05
# Bathroom                                                2.795e+05   1.67e+05      1.674      0.094   -4.78e+04    6.07e+05
# Bathroom:Bedroom2_Group_1[T.True]                       1.461e+05   2.03e+05      0.721      0.471   -2.51e+05    5.43e+05
# Bathroom:Bedroom2_Group_2_3[T.True]                    -6.113e+04   1.67e+05     -0.366      0.715   -3.89e+05    2.67e+05
# Bathroom:Bedroom2_Group_4_5[T.True]                     7.792e+04   1.68e+05      0.465      0.642   -2.51e+05    4.07e+05
# Bathroom:Bedroom2_Group_6_or_more[T.True]              -1.363e+05   1.86e+05     -0.732      0.464   -5.02e+05    2.29e+05
# HouseAge                                                1696.3915    154.792     10.959      0.000    1392.946    1999.837
# BuildingArea                                             337.4503     96.702      3.490      0.000     147.880     527.021
# BuildingArea:RegionGroup_E_Metropolitan[T.True]          -65.2082    226.252     -0.288      0.773    -508.740     378.324
# BuildingArea:RegionGroup_N_S_SE_Metropolitan[T.True]     836.6341    104.182      8.031      0.000     632.401    1040.867
# BuildingArea:RegionGroup_W_Metropolitan[T.True]         -433.9757    163.215     -2.659      0.008    -753.934    -114.017
# ==============================================================================
# Omnibus:                     2551.515   Durbin-Watson:                   1.412
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            30880.396
# Skew:                           1.621   Prob(JB):                         0.00
# Kurtosis:                      13.419   Cond. No.                     1.19e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.12e-23. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# Test

# %%
model_name = "Model 6"
predictions = model.predict(test_data)
mse = mean_squared_error(test_data['Price'], predictions)
rmse = np.sqrt(mse)
mae = mean_absolute_error(test_data['Price'], predictions)
print(f"Root Mean Squared Error: {rmse}")
print(f"Mean Absolute Error: {mae}")

metrics_df = pd.concat([
    metrics_df,
    pd.DataFrame({'Model': [model_name], 'MSE': [mse], 'RMSE': [rmse], 'MAE': [mae]})
], ignore_index=True)

metrics_df
# Out:
# Root Mean Squared Error: 445476.568404045
# Mean Absolute Error: 313668.52438617684
#      Model           MSE           RMSE            MAE
# 0  Model 1  2.786938e+11  527914.570199  335634.221397
# 1  Model 2  2.053694e+11  453177.040865  315777.482255
# 2  Model 3  1.977586e+11  444700.585541  313349.922157
# 3  Model 4  1.975604e+11  444477.711104  313331.518302
# 4  Model 5  1.981216e+11  445108.495834  313353.617289
# 5  Model 6  1.984494e+11  445476.568404  313668.524386

# %%
plt.figure(figsize=(10, 6))
max_price = max(max(test_data['Price']), max(predictions))
min_price = min(min(test_data['Price']), min(predictions)) 
plt.plot([min_price, max_price], [min_price, max_price], color='red', linestyle='--', label='Perfect Prediction')
plt.scatter(test_data['Price'], predictions, alpha=0.7, color='blue', label='Predicted vs Actual')
plt.title('Actual vs Predicted Prices')
plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Model 7 - all features, with interactions - MORE INTERPRETABLE INTERACTONS
# - BuildingArea * RegionGroup
# - Bathroom * Bedroom2_Group

# %% [markdown]
# Training

# %%
model = smf.ols('Price ~ Distance + Landsize + Rooms + Bathroom*Bedroom2_Group_1 + Bathroom*Bedroom2_Group_2_3 + Bathroom*Bedroom2_Group_4_5 + Bathroom*Bedroom2_Group_6_or_more + Car_1 + Car_2 + Car_3 + Car_4 + HouseAge + BuildingArea*RegionGroup_E_Metropolitan + BuildingArea*RegionGroup_N_S_SE_Metropolitan + BuildingArea*RegionGroup_W_Metropolitan + Type_t + Type_u + Method_PI + Method_SA + Method_SP + Method_VB', train_data).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.594
# Model:                            OLS   Adj. R-squared:                  0.592
# Method:                 Least Squares   F-statistic:                     323.3
# Date:                Tue, 07 Jan 2025   Prob (F-statistic):               0.00
# Time:                        03:41:39   Log-Likelihood:                -89258.
# No. Observations:                6225   AIC:                         1.786e+05
# Df Residuals:                    6196   BIC:                         1.788e+05
# Df Model:                          28
# Covariance Type:            nonrobust
# ========================================================================================================================
#                                                            coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------
# Intercept                                             4.761e+05   1.61e+05      2.954      0.003     1.6e+05    7.92e+05
# Bedroom2_Group_1[T.True]                             -4.164e+05   2.45e+05     -1.696      0.090   -8.98e+05    6.48e+04
# Bedroom2_Group_2_3[T.True]                           -1.174e+05   2.13e+05     -0.552      0.581   -5.34e+05       3e+05
# Bedroom2_Group_4_5[T.True]                           -3.136e+05   2.16e+05     -1.454      0.146   -7.37e+05    1.09e+05
# Bedroom2_Group_6_or_more[T.True]                     -7.289e+04   3.28e+05     -0.222      0.824   -7.15e+05     5.7e+05
# Car_1[T.True]                                        -1.149e+04    2.2e+04     -0.522      0.601   -5.46e+04    3.16e+04
# Car_2[T.True]                                         7.688e+04   2.34e+04      3.287      0.001     3.1e+04    1.23e+05
# Car_3[T.True]                                         9.977e+04   2.91e+04      3.430      0.001    4.27e+04    1.57e+05
# Car_4[T.True]                                         7.381e+04   6.73e+04      1.097      0.273   -5.81e+04    2.06e+05
# RegionGroup_E_Metropolitan[T.True]                    2.059e+05   6.46e+04      3.186      0.001    7.92e+04    3.33e+05
# RegionGroup_N_S_SE_Metropolitan[T.True]               1.478e+05   5.55e+04      2.660      0.008    3.89e+04    2.57e+05
# RegionGroup_W_Metropolitan[T.True]                    1.225e+05   5.88e+04      2.085      0.037    7302.232    2.38e+05
# Type_t[T.True]                                       -1.511e+05   2.11e+04     -7.153      0.000   -1.92e+05    -1.1e+05
# Type_u[T.True]                                       -2.274e+05   1.69e+04    -13.422      0.000   -2.61e+05   -1.94e+05
# Method_PI[T.True]                                    -1.024e+05   1.62e+04     -6.329      0.000   -1.34e+05   -7.07e+04
# Method_SA[T.True]                                    -6452.1766   8.57e+04     -0.075      0.940   -1.74e+05    1.62e+05
# Method_SP[T.True]                                    -8.097e+04   1.64e+04     -4.926      0.000   -1.13e+05   -4.87e+04
# Method_VB[T.True]                                    -6.015e+04   1.87e+04     -3.209      0.001   -9.69e+04   -2.34e+04
# Distance                                             -4.881e+04   1743.518    -27.995      0.000   -5.22e+04   -4.54e+04
# Landsize                                               472.2604     28.099     16.807      0.000     417.177     527.344
# Rooms                                                 1.151e+05   1.15e+04     10.047      0.000    9.26e+04    1.38e+05
# Bathroom                                               2.86e+05   1.68e+05      1.706      0.088   -4.27e+04    6.15e+05
# Bathroom:Bedroom2_Group_1[T.True]                     1.475e+05   2.04e+05      0.725      0.469   -2.52e+05    5.46e+05
# Bathroom:Bedroom2_Group_2_3[T.True]                  -6.588e+04   1.68e+05     -0.392      0.695   -3.95e+05    2.63e+05
# Bathroom:Bedroom2_Group_4_5[T.True]                   7.416e+04   1.68e+05      0.441      0.660   -2.56e+05    4.04e+05
# Bathroom:Bedroom2_Group_6_or_more[T.True]            -1.459e+05   1.87e+05     -0.780      0.435   -5.13e+05    2.21e+05
# HouseAge                                              1733.8705    155.277     11.166      0.000    1429.474    2038.267
# BuildingArea                                           139.2785     92.688      1.503      0.133     -42.423     320.980
# BuildingArea:RegionGroup_E_Metropolitan[T.True]       -354.0074    208.448     -1.698      0.090    -762.637      54.623
# BuildingArea:RegionGroup_N_S_SE_Metropolitan[T.True]  1129.9690     96.174     11.749      0.000     941.434    1318.504
# BuildingArea:RegionGroup_W_Metropolitan[T.True]       -636.6832    150.483     -4.231      0.000    -931.682    -341.685
# ==============================================================================
# Omnibus:                     2527.068   Durbin-Watson:                   1.421
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            31128.651
# Skew:                           1.596   Prob(JB):                         0.00
# Kurtosis:                      13.480   Cond. No.                     7.91e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.52e-23. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# Test

# %%
model_name = "Model 7"
predictions = model.predict(test_data)
mse = mean_squared_error(test_data['Price'], predictions)
rmse = np.sqrt(mse)
mae = mean_absolute_error(test_data['Price'], predictions)
print(f"Root Mean Squared Error: {rmse}")
print(f"Mean Absolute Error: {mae}")

metrics_df = pd.concat([
    metrics_df,
    pd.DataFrame({'Model': [model_name], 'MSE': [mse], 'RMSE': [rmse], 'MAE': [mae]})
], ignore_index=True)

metrics_df
# Out:
# Root Mean Squared Error: 445483.7497254412
# Mean Absolute Error: 313773.92744164245
#      Model           MSE           RMSE            MAE
# 0  Model 1  2.786938e+11  527914.570199  335634.221397
# 1  Model 2  2.053694e+11  453177.040865  315777.482255
# 2  Model 3  1.977586e+11  444700.585541  313349.922157
# 3  Model 4  1.975604e+11  444477.711104  313331.518302
# 4  Model 5  1.981216e+11  445108.495834  313353.617289
# 5  Model 6  1.984494e+11  445476.568404  313668.524386
# 6  Model 7  1.984558e+11  445483.749725  313773.927442

# %%
plt.figure(figsize=(10, 6))
max_price = max(max(test_data['Price']), max(predictions))
min_price = min(min(test_data['Price']), min(predictions)) 
plt.plot([min_price, max_price], [min_price, max_price], color='red', linestyle='--', label='Perfect Prediction')
plt.scatter(test_data['Price'], predictions, alpha=0.7, color='blue', label='Predicted vs Actual')
plt.title('Actual vs Predicted Prices')
plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Model 8  - all features, with interactions - MORE INTERPRETABLE INTERACTONS
# - BuildingArea * RegionGroup
# - Method * RegionGroup

# %% [markdown]
# Training

# %%
model = smf.ols('Price ~ Distance + Landsize + Rooms + Bathroom + Bedroom2_Group_1 + Bedroom2_Group_2_3 + Bedroom2_Group_4_5 + Bedroom2_Group_6_or_more + Car_1 + Car_2 + Car_3 + Car_4 + HouseAge + BuildingArea*RegionGroup_E_Metropolitan + BuildingArea*RegionGroup_N_S_SE_Metropolitan + BuildingArea*RegionGroup_W_Metropolitan + Type_t + Type_u + RegionGroup_W_Metropolitan*Method_PI + RegionGroup_W_Metropolitan*Method_SA + RegionGroup_W_Metropolitan*Method_SP + RegionGroup_W_Metropolitan*Method_VB + RegionGroup_N_S_SE_Metropolitan*Method_PI + RegionGroup_N_S_SE_Metropolitan*Method_SA + RegionGroup_N_S_SE_Metropolitan*Method_SP + RegionGroup_N_S_SE_Metropolitan*Method_VB + RegionGroup_E_Metropolitan*Method_PI + RegionGroup_E_Metropolitan*Method_SA + RegionGroup_E_Metropolitan*Method_SP + RegionGroup_E_Metropolitan*Method_VB', train_data).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.591
# Model:                            OLS   Adj. R-squared:                  0.589
# Method:                 Least Squares   F-statistic:                     288.4
# Date:                Tue, 07 Jan 2025   Prob (F-statistic):               0.00
# Time:                        03:41:39   Log-Likelihood:                -89280.
# No. Observations:                6225   AIC:                         1.786e+05
# Df Residuals:                    6193   BIC:                         1.788e+05
# Df Model:                          31
# Covariance Type:            nonrobust
# =============================================================================================================================
#                                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------------
# Intercept                                                  4.926e+05   1.02e+05      4.821      0.000    2.92e+05    6.93e+05
# Bedroom2_Group_1[T.True]                                  -2.693e+05   1.33e+05     -2.023      0.043    -5.3e+05   -8301.878
# Bedroom2_Group_2_3[T.True]                                -1.946e+05    1.3e+05     -1.492      0.136    -4.5e+05    6.11e+04
# Bedroom2_Group_4_5[T.True]                                 -1.21e+05   1.32e+05     -0.920      0.358   -3.79e+05    1.37e+05
# Bedroom2_Group_6_or_more[T.True]                          -4.363e+05   1.54e+05     -2.826      0.005   -7.39e+05   -1.34e+05
# Car_1[T.True]                                             -1.963e+04    2.2e+04     -0.892      0.372   -6.28e+04    2.35e+04
# Car_2[T.True]                                               6.43e+04   2.34e+04      2.749      0.006    1.84e+04     1.1e+05
# Car_3[T.True]                                               9.13e+04   2.92e+04      3.131      0.002    3.41e+04    1.48e+05
# Car_4[T.True]                                              8.123e+04   6.75e+04      1.203      0.229   -5.11e+04    2.14e+05
# RegionGroup_E_Metropolitan[T.True]                         2.091e+05   5.06e+04      4.131      0.000     1.1e+05    3.08e+05
# RegionGroup_N_S_SE_Metropolitan[T.True]                    1.617e+05   3.73e+04      4.334      0.000    8.86e+04    2.35e+05
# RegionGroup_W_Metropolitan[T.True]                         1.218e+05   4.22e+04      2.885      0.004     3.9e+04    2.05e+05
# Type_t[T.True]                                            -1.629e+05   2.11e+04     -7.711      0.000   -2.04e+05   -1.21e+05
# Type_u[T.True]                                            -2.214e+05    1.7e+04    -13.038      0.000   -2.55e+05   -1.88e+05
# Method_PI[T.True]                                         -7.756e+04    1.8e+04     -4.304      0.000   -1.13e+05   -4.22e+04
# Method_SA[T.True]                                         -3.026e+04   6.95e+04     -0.435      0.663   -1.67e+05    1.06e+05
# Method_SP[T.True]                                         -4.176e+04   1.81e+04     -2.312      0.021   -7.72e+04   -6353.277
# Method_VB[T.True]                                         -5.485e+04   2.12e+04     -2.592      0.010   -9.63e+04   -1.34e+04
# RegionGroup_W_Metropolitan[T.True]:Method_PI[T.True]       9215.9196   3.24e+04      0.285      0.776   -5.42e+04    7.27e+04
# RegionGroup_W_Metropolitan[T.True]:Method_SA[T.True]      -8.199e+04   1.27e+05     -0.645      0.519   -3.31e+05    1.67e+05
# RegionGroup_W_Metropolitan[T.True]:Method_SP[T.True]       1.274e+04   2.74e+04      0.465      0.642   -4.09e+04    6.64e+04
# RegionGroup_W_Metropolitan[T.True]:Method_VB[T.True]      -4.413e+04   3.86e+04     -1.144      0.253    -1.2e+05    3.15e+04
# RegionGroup_N_S_SE_Metropolitan[T.True]:Method_PI[T.True] -2.719e+04   2.23e+04     -1.218      0.223   -7.09e+04    1.66e+04
# RegionGroup_N_S_SE_Metropolitan[T.True]:Method_SA[T.True]  5.172e+04   8.93e+04      0.579      0.562   -1.23e+05    2.27e+05
# RegionGroup_N_S_SE_Metropolitan[T.True]:Method_SP[T.True] -7.368e+04   2.34e+04     -3.145      0.002    -1.2e+05   -2.78e+04
# RegionGroup_N_S_SE_Metropolitan[T.True]:Method_VB[T.True]  5183.2444    2.6e+04      0.200      0.842   -4.57e+04    5.61e+04
# RegionGroup_E_Metropolitan[T.True]:Method_PI[T.True]      -5.958e+04   4.47e+04     -1.332      0.183   -1.47e+05    2.81e+04
# RegionGroup_E_Metropolitan[T.True]:Method_SA[T.True]      -2.555e-11   2.79e-11     -0.917      0.359   -8.01e-11     2.9e-11
# RegionGroup_E_Metropolitan[T.True]:Method_SP[T.True]       1.918e+04   4.78e+04      0.401      0.688   -7.45e+04    1.13e+05
# RegionGroup_E_Metropolitan[T.True]:Method_VB[T.True]       -1.59e+04   5.22e+04     -0.305      0.761   -1.18e+05    8.64e+04
# Distance                                                  -4.835e+04   1749.353    -27.640      0.000   -5.18e+04   -4.49e+04
# Landsize                                                    480.9731     28.250     17.026      0.000     425.594     536.353
# Rooms                                                      1.084e+05   1.14e+04      9.488      0.000     8.6e+04    1.31e+05
# Bathroom                                                   2.689e+05   1.04e+04     25.782      0.000    2.48e+05    2.89e+05
# HouseAge                                                   1729.0509    155.954     11.087      0.000    1423.327    2034.775
# BuildingArea                                                173.5724     93.083      1.865      0.062      -8.902     356.047
# BuildingArea:RegionGroup_E_Metropolitan[T.True]            -302.5105    209.867     -1.441      0.150    -713.923     108.902
# BuildingArea:RegionGroup_N_S_SE_Metropolitan[T.True]       1124.4576     96.834     11.612      0.000     934.629    1314.286
# BuildingArea:RegionGroup_W_Metropolitan[T.True]            -648.3746    151.494     -4.280      0.000    -945.355    -351.394
# ==============================================================================
# Omnibus:                     2487.334   Durbin-Watson:                   1.425
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            30021.910
# Skew:                           1.570   Prob(JB):                         0.00
# Kurtosis:                      13.290   Cond. No.                     1.19e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.12e-23. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# Test

# %%
model_name = "Model 8"
predictions = model.predict(test_data)
mse = mean_squared_error(test_data['Price'], predictions)
rmse = np.sqrt(mse)
mae = mean_absolute_error(test_data['Price'], predictions)
print(f"Root Mean Squared Error: {rmse}")
print(f"Mean Absolute Error: {mae}")

metrics_df = pd.concat([
    metrics_df,
    pd.DataFrame({'Model': [model_name], 'MSE': [mse], 'RMSE': [rmse], 'MAE': [mae]})
], ignore_index=True)

metrics_df
# Out:
# Root Mean Squared Error: 444451.6773870593
# Mean Absolute Error: 313183.69471564575
#      Model           MSE           RMSE            MAE
# 0  Model 1  2.786938e+11  527914.570199  335634.221397
# 1  Model 2  2.053694e+11  453177.040865  315777.482255
# 2  Model 3  1.977586e+11  444700.585541  313349.922157
# 3  Model 4  1.975604e+11  444477.711104  313331.518302
# 4  Model 5  1.981216e+11  445108.495834  313353.617289
# 5  Model 6  1.984494e+11  445476.568404  313668.524386
# 6  Model 7  1.984558e+11  445483.749725  313773.927442
# 7  Model 8  1.975373e+11  444451.677387  313183.694716

# %%
plt.figure(figsize=(10, 6))
max_price = max(max(test_data['Price']), max(predictions))
min_price = min(min(test_data['Price']), min(predictions)) 
plt.plot([min_price, max_price], [min_price, max_price], color='red', linestyle='--', label='Perfect Prediction')
plt.scatter(test_data['Price'], predictions, alpha=0.7, color='blue', label='Predicted vs Actual')
plt.title('Actual vs Predicted Prices')
plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Models Comparison - metrics

# %%
metrics_df[['MSE', 'RMSE', 'MAE']] = metrics_df[['MSE', 'RMSE', 'MAE']].round(2)
sorted_metrics_df = metrics_df[['Model', 'RMSE']].sort_values(by='RMSE', ascending=False)
sorted_metrics_df
# Out:
#      Model       RMSE
# 0  Model 1  527914.57
# 1  Model 2  453177.04
# 6  Model 7  445483.75
# 5  Model 6  445476.57
# 4  Model 5  445108.50
# 2  Model 3  444700.59
# 3  Model 4  444477.71
# 7  Model 8  444451.68
